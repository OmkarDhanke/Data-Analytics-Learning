# %% [markdown]
# ## Strings

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
skill = 'Python'

# %%
print(skill)
type(skill)
# Out:
# Python
# str

# %%
skill.lower()
# Out:
# 'python'

# %%
skill.upper()
# Out:
# 'PYTHON'

# %%
skill.replace('P','J')
# Out:
# 'Jython'

# %%
job_title = "Data analyst"

# %%
job_title.replace('a','o',2)
# Out:
# 'Doto analyst'

# %%
df = ' Omkar Dhanke  '
print(df)
# Out:
#  Omkar Dhanke

# %%
z = df.strip()
print(z)
# Out:
# Omkar Dhanke

# %%
z[0:7]
# Out:
# 'Omkar D'

# %%
z.split()
# Out:
# ['Omkar', 'Dhanke']
