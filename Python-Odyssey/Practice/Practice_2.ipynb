# %% [markdown]
# ## Basic Data Types
# 1. Text
# 2. List
# 3. set
# 4. Boolean

# %%
total_salary = 10000
bonus_salary = 1000

# %%
type(total_salary)
# Out:
# int

# %%
base_salary = total_salary - bonus_salary
print(base_salary)
# Out:
# 9000
