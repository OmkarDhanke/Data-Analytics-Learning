# %% [markdown]
# # **Day 16**

# %%
def add(*item):
  return list(item)
add(1,2,3,4)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # Anonimas function lambda

# %%
lambda a,b: a+b
mi(20,30)
# Out:
# (20, 30)

# %%
aot = lambda b, h: 0.5 * b * h
aot(20,7)
# Out:
# 70.0
