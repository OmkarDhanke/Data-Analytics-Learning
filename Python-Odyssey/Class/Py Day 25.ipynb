# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Adding Colum Name / Header

# %%
col = ["sr","City","Institute","Subject","State","Time"]
a = pd.read_table("course.csv",sep=",",header=None,names=col)

# %%
col = ["Sr","Age","Gender","Job","Num"]
a = pd.read_table("psd.user.txt",sep="|",header=None,names=col)

# %%
a
# Out:
#       Sr  Age Gender            Job    Num
# 0      1   24      M     technician  85711
# 1      2   53      F          other  94043
# 2      3   23      M         writer  32067
# 3      4   24      M     technician  43537
# 4      5   33      F          other  15213
# ..   ...  ...    ...            ...    ...
# 938  939   26      F        student  33319
# 939  940   32      M  administrator  02215
# 940  941   20      M        student  97229
# 941  942   48      F      librarian  78209
# 942  943   22      M        student  77841
#
# [943 rows x 5 columns]

# %% [markdown]
# # 2. Adding a New Colum

# %%
a.Job+"|"+a.Gender
# Out:
# 0         technician|M
# 1              other|F
# 2             writer|M
# 3         technician|M
# 4              other|F
#             ...
# 938          student|F
# 939    administrator|M
# 940          student|M
# 941        librarian|F
# 942          student|M
# Length: 943, dtype: object

# %%
a["Age_Num"] = a["Age"].astype(str) + "|" + a.Num.astype(str)

# %%
a
# Out:
#       Sr  Age Gender            Job    Num   Age_Num
# 0      1   24      M     technician  85711  24|85711
# 1      2   53      F          other  94043  53|94043
# 2      3   23      M         writer  32067  23|32067
# 3      4   24      M     technician  43537  24|43537
# 4      5   33      F          other  15213  33|15213
# ..   ...  ...    ...            ...    ...       ...
# 938  939   26      F        student  33319  26|33319
# 939  940   32      M  administrator  02215  32|02215
# 940  941   20      M        student  97229  20|97229
# 941  942   48      F      librarian  78209  48|78209
# 942  943   22      M        student  77841  22|77841
#
# [943 rows x 6 columns]

# %%
a.Age_Num
# Out:
# 0      24|85711
# 1      53|94043
# 2      23|32067
# 3      24|43537
# 4      33|15213
#          ...
# 938    26|33319
# 939    32|02215
# 940    20|97229
# 941    48|78209
# 942    22|77841
# Name: Age_Num, Length: 943, dtype: object

# %%
m = pd.read_xml("animelist.xml")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipython-input-2257538139.py in <cell line: 0>()
# ----> 1 m = pd.read_xml("animelist.xml")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/xml.py in read_xml(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, dtype, converters, parse_dates, encoding, parser, stylesheet, iterparse, compression, storage_options, dtype_backend)
#    1158     check_dtype_backend(dtype_backend)
#    1159
# -> 1160     return _parse(
#    1161         path_or_buffer=path_or_buffer,
#    1162         xpath=xpath,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/xml.py in _parse(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, dtype, converters, parse_dates, encoding, parser, stylesheet, iterparse, compression, storage_options, dtype_backend, **kwargs)
# ...

# %% [markdown]
# # 3. Deleteing colum

# %%
a
# Out:
#       Sr  Age Gender            Job    Num   Age_Num
# 0      1   24      M     technician  85711  24|85711
# 1      2   53      F          other  94043  53|94043
# 2      3   23      M         writer  32067  23|32067
# 3      4   24      M     technician  43537  24|43537
# 4      5   33      F          other  15213  33|15213
# ..   ...  ...    ...            ...    ...       ...
# 938  939   26      F        student  33319  26|33319
# 939  940   32      M  administrator  02215  32|02215
# 940  941   20      M        student  97229  20|97229
# 941  942   48      F      librarian  78209  48|78209
# 942  943   22      M        student  77841  22|77841
#
# [943 rows x 6 columns]

# %%
# This will delete the Colom remprory
a.drop("Job",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2675744364.py in <cell line: 0>()
#       1 # This will delete the Colom remprory
# ----> 2 a.drop("Job",axis=1)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
a
# Out:
#       Sr  Age Gender            Job    Num   Age_Num
# 0      1   24      M     technician  85711  24|85711
# 1      2   53      F          other  94043  53|94043
# 2      3   23      M         writer  32067  23|32067
# 3      4   24      M     technician  43537  24|43537
# 4      5   33      F          other  15213  33|15213
# ..   ...  ...    ...            ...    ...       ...
# 938  939   26      F        student  33319  26|33319
# 939  940   32      M  administrator  02215  32|02215
# 940  941   20      M        student  97229  20|97229
# 941  942   48      F      librarian  78209  48|78209
# 942  943   22      M        student  77841  22|77841
#
# [943 rows x 6 columns]

# %%
# To permently delete
a.drop("Job",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1887060935.py in <cell line: 0>()
#       1 # To permently delete
# ----> 2 a.drop("Job",axis=1,inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
a
# Out:
#       Sr  Age Gender    Num   Age_Num
# 0      1   24      M  85711  24|85711
# 1      2   53      F  94043  53|94043
# 2      3   23      M  32067  23|32067
# 3      4   24      M  43537  24|43537
# 4      5   33      F  15213  33|15213
# ..   ...  ...    ...    ...       ...
# 938  939   26      F  33319  26|33319
# 939  940   32      M  02215  32|02215
# 940  941   20      M  97229  20|97229
# 941  942   48      F  78209  48|78209
# 942  943   22      M  77841  22|77841
#
# [943 rows x 5 columns]

# %%
a.drop(["Sr","Gender"],axis=1,inplace=None)
# Out:
#      Age    Num   Age_Num
# 0     24  85711  24|85711
# 1     53  94043  53|94043
# 2     23  32067  23|32067
# 3     24  43537  24|43537
# 4     33  15213  33|15213
# ..   ...    ...       ...
# 938   26  33319  26|33319
# 939   32  02215  32|02215
# 940   20  97229  20|97229
# 941   48  78209  48|78209
# 942   22  77841  22|77841
#
# [943 rows x 3 columns]

# %%
a
# Out:
#       Sr  Age Gender    Num   Age_Num
# 0      1   24      M  85711  24|85711
# 1      2   53      F  94043  53|94043
# 2      3   23      M  32067  23|32067
# 3      4   24      M  43537  24|43537
# 4      5   33      F  15213  33|15213
# ..   ...  ...    ...    ...       ...
# 938  939   26      F  33319  26|33319
# 939  940   32      M  02215  32|02215
# 940  941   20      M  97229  20|97229
# 941  942   48      F  78209  48|78209
# 942  943   22      M  77841  22|77841
#
# [943 rows x 5 columns]

# %%
a.drop(["Sr","Gender"],axis=1,inplace=True)

# %%
a
# Out:
#      Age    Num   Age_Num
# 0     24  85711  24|85711
# 1     53  94043  53|94043
# 2     23  32067  23|32067
# 3     24  43537  24|43537
# 4     33  15213  33|15213
# ..   ...    ...       ...
# 938   26  33319  26|33319
# 939   32  02215  32|02215
# 940   20  97229  20|97229
# 941   48  78209  48|78209
# 942   22  77841  22|77841
#
# [943 rows x 3 columns]

# %%
a.drop(index=2,axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-881855285.py in <cell line: 0>()
# ----> 1 a.drop(index=2,axis=1,inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
a
# Out:
#      Age    Num   Age_Num
# 0     24  85711  24|85711
# 1     53  94043  53|94043
# 3     24  43537  24|43537
# 4     33  15213  33|15213
# 5     42  98101  42|98101
# ..   ...    ...       ...
# 938   26  33319  26|33319
# 939   32  02215  32|02215
# 940   20  97229  20|97229
# 941   48  78209  48|78209
# 942   22  77841  22|77841
#
# [942 rows x 3 columns]

# %%
a.drop([4,5,6,7],axis=0,inplace=True)

# %%
a
# Out:
#      Age    Num   Age_Num
# 0     24  85711  24|85711
# 1     53  94043  53|94043
# 3     24  43537  24|43537
# 8     29  01002  29|01002
# 9     53  90703  53|90703
# ..   ...    ...       ...
# 938   26  33319  26|33319
# 939   32  02215  32|02215
# 940   20  97229  20|97229
# 941   48  78209  48|78209
# 942   22  77841  22|77841
#
# [938 rows x 3 columns]
