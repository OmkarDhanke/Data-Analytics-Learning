# %%
1234
# Out:
# 1234

# %%
# Int
print(123)
print(type(-123))
print(type(123))
# Out:
# 123
# <class 'int'>
# <class 'int'>

# %%
# Float
print(1.10)
print(-2.21)
print(type (-2.25))
# Out:
# 1.1
# -2.21
# <class 'float'>

# %%
# Complex
print(3+4j)
print(3+50j)
print(type(3+50j))
# Out:
# (3+4j)
# (3+50j)
# <class 'complex'>

# %%
print(-553 + 45646j)
print(2.25 + 245j)
print(type (2.25 + -245))
# Out:
# (-553+45646j)
# (2.25+245j)
# <class 'float'>

# %%
# String
print('Hello World')
print("I can't sleep")
print(type("Hello World"))
print('''classification or categorization
of data are called
Data Type.''')
# Out:
# Hello World
# I can't sleep
# <class 'str'>
# classification or categorization
# of data are called
# Data Type.

# %%
# tuple
print((1,2,3,"One"))
print(type((1,2,3,"One")))
# Out:
# (1, 2, 3, 'One')
# <class 'tuple'>

# %%
# tule
print(("i have" , 1 , 'apple'))
# Out:
# ('i have', 1, 'apple')

# %%
print(chr(1000464))
# Out:
# 󴐐

# %%
chr(2323)
# Out:
# 'ओ'

# %%
chr(23568)
# Out:
# '尐'
