# %%
aritmatic

# %%
a=20
b=2
print(a+b)
print(a-b)
print(a*b)
print(a%b)
print(a/b)
print(a//b)
# Out:
# 22
# 18
# 40
# 0
# 10.0
# 10

# %% [markdown]
# comparison

# %%
x=20
y=22
print(x>y)
print(y>x)
print(y!=x)
print(x==y)
print(y>=x)
print(x!=y)
print(x<y)
# Out:
# False
# True
# True
# False
# True
# True
# True

# %%
print((x+2)==y)
# Out:
# True

# %%
print(22==(x+y))
print(((x+y)-22)!=20)
# Out:
# False
# False

# %%
print(((x-y)+2)==0)
# Out:
# True

# %%
l={1,2}
m={3,4}
print((l+m)=={1,2,3,4})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1034828351.py in <cell line: 0>()
#       1 l={1,2}
#       2 m={3,4}
# ----> 3 print((l+m)=={1,2,3,4})
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
l={1,2}
m={3,4}
print((l|m)=={1,2,3,4})
# Out:
# True

# %% [markdown]
# Logical

# %%
a=20
b=30
print((a!=b)or(a==b))
print(True or False)
print((a+10)==b)
print((a+10)and(a!=b))
print(30 and 20)
print(False and (1-1))
print(a!=b)and not(a==b)
# Out:
# True
# True
# True
# True
# 20
# False
# True

# %% [markdown]
# identity

# %%
a=(1,2)
b=(1,2)
print(a is (1,2))
print((1,2) is a)
print(a is not b)
# Out:
# False
# False
# True
# <>:3: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
# /tmp/ipython-input-1340015264.py:3: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
#   print(a is (1,2))
# /tmp/ipython-input-1340015264.py:4: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
#   print((1,2) is a)

# %% [markdown]
# membership

# %%
a=(1,2)
print(2 in a)
print(3 in a)
print(((1,2)) in a)
print(6 not in a)
x=[1,2,(1,2)]
print(a in x)
print(1 not in a and 2 in x)
print(a in (1,2))
# Out:
# True
# False
# False
# True
# True
# False
# False

# %%
print(6 not in 6)
print(a in 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2285092236.py in <cell line: 0>()
# ----> 1 print(6 not in 6)
#       2 print(a in 1)
#
# TypeError: argument of type 'int' is not iterable

# %% [markdown]
# assignment

# %%
a=20
a+=2
print(a)
a-=2
print(a)
a%=2
print(a)
a/=2
print(a)
a*=2
print(a)
a//=2
print(a)
# Out:
# 22
# 20
# 0
# 0.0
# 0.0
# 0.0

# %%
a=20
a+=11
print(a)
a-=11
print(a)
a%=11
print(a)
a/=11
print(a)
a*=11
print(a)
a//=11
print(a)
# Out:
# 31
# 20
# 9
# 0.8181818181818182
# 9.0
# 0.0

# %%
a=20
a+=27
print(a)
a-=27
print(a)
a%=27
print(a)
a/=27
print(a)
a*=27
print(a)
a//=27
print(a)
# Out:
# 47
# 20
# 20
# 0.7407407407407407
# 20.0
# 0.0

# %%
a=20
a+=29
print(a)
a-=29
print(a)
a%=29
print(a)
a/=29
print(a)
a*=29
print(a)
a//=29
print(a)
# Out:
# 49
# 20
# 20
# 0.6896551724137931
# 20.0
# 0.0
