# %% [markdown]
# # Sring Slicing

# %%
# Slicing
x = 'my name is omkar and i love python'

z = x[0:10:1]

print(z)
# Out:
# my name is

# %%
x = 'my name is omkar and i love python'

z = x[0:10:1] + x[-7::1]

print(z)
# Out:
# my name is python

# %%
x = 'my name is omkar and i love python'

z = x[0:10:1] + x[-7::1] + x[-18:-7:1]

print(z)
# Out:
# my name is python and i love

# %%
x = 'my name is omkar and i love python'

z = x[0:10:1] + x[-7::1] + x[-18:-7:1] + x[10:16:1]

print(z)
# Out:
# my name is python and i love omkar

# %%
x = 'my name is omkar and i love python'

z = x[0:10:1] + x[-7::1] + x[-18:-7:1] + x[10:16:1]

print(z)

print(x[-1:-10:1])

print(x[16:6:-1])
# Out:
# my name is python and i love omkar
#
#  rakmo si

# %%
x = 'my name is omkar and i love python'

z = x[0:10:1] + x[-7::1] + x[-18:-7:1] + x[10:16:1]

print(x[4:-1:-1])

# %%
x = 'my name is omkar and i love python'

z = x[0:10:1] + x[-7::1] + x[-18:-7:1] + x[10:16:1]

print(x[-1:4:-1])
# Out:
# nohtyp evol i dna rakmo si em

# %%
x = 'my name is omkar and i love python'

z = x[0:10:1] + x[-7::1] + x[-18:-7:1] + x[10:16:1]

print(x[5:-7:1])
# Out:
# me is omkar and i love

# %%
x = 'My name is a omkar'

z = x[0:10:1] + x[1]

print(z)
# Out:
# My name isy

# %%
# list
r = [1,6,7,5,4,'R',2,6]

v = r[-3:2:-1] + r[0:3:1]

print(v)
# Out:
# ['R', 4, 5, 1, 6, 7]

# %%
# Tuple
r = [1,6,7,5,4,'R',2,6]

c = r[-3:-7:-1]

print(['Omkar'] + c)
# Out:
# ['Omkar', 'R', 4, 5, 7]

# %%
# tuple
r = 'raj'
m = tuple(r)
print(m)
('Raj')
# Out:
# ('r', 'a', 'j')
# 'Raj'

# %%
# Set
s = 'veer'
t = set(s)
print(t)
# Out:
# {'e', 'v', 'r'}

# %%
# list
a = 'omakr'
b = list(a)
print(b)
# Out:
# ['o', 'm', 'a', 'k', 'r']

# %%
# string
c = 'omkar'
d = str(c)
print(d)
# Out:
# omkar

# %%
a = '2'
b = list(tuple(set(list(str(a)))))
print(b)
# Out:
# ['2']

# %%
c = list(print(set(str(a))))
print(c)
# Out:
# {',', '3', '1', '2'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1277269426.py in <cell line: 0>()
# ----> 1 c = list(print(set(str(a))))
#       2 print(c)
#
# TypeError: 'NoneType' object is not iterable

# %%
a = [1,2,3,5]

b = print(print(tuple[a[2]+ a[0]]))
# Out:
# tuple[4]
# None

# %% [markdown]
# # **Methos**

# %% [markdown]
# ### 1. **Strings**

# %%
# Strings
a = 'i lOvE PyThon'
print(id(a))

# a = a.upper()
# print(a)
# print(id(a))
# Out:
# 139836042846640

# %%
print(a.lower())
print(a.title())
print(a.capitalize())
print(a.swapcase())
print(a.replace('PyThon','java'))
print(a.count('O'))
print(a.index('P'))
print(a.find('p'))
print(len(a))
# Out:
# i love python
# I Love Python
# I love python
# I LoVe pYtHON
# i lOvE java
# 1
# 7
# -1
# 13
